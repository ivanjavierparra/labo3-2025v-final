# %%
import pandas as pd
import gc
import numpy as np
from sklearn.preprocessing import StandardScaler, RobustScaler
import tensorflow as tf

# %%
# ---------------------------------------------
# configuracion del modelo LSTM:
# ---------------------------------------------
config = {
        # Arquitectura
        "result_name": "lstm_5q_share_withmonth",
        "lstm_units_1": 64,
        "lstm_units_2": 32,
        "dense_units": 16,
        "dropout_rate": 0.3,
        "seed": 42,  # Para reproducibilidad
        # Entrenamiento
        "epochs": 150,
        "batch_size": 64,
        "early_stopping_patience": 30,
        "learning_rate": None,  # Si querés usar Adam con tasa específica

        # Regularización
        "l2_lambda": 0.001,

        # Optimizador
        "optimizer": "rmsprop",  # adam, sgd, rmsprop, etc.

        # Preprocesamiento
        "scaler_name": "robust",  # standard o robust

        # Ventana temporal
        "window_size": 6,
        "feature_cols" : ['tn'],
        "products_to_train": None,  # Filtrar productos entre 50 y 150
    }

# %%
# ---------------------------------------------
# datos:
# ---------------------------------------------
df = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/sell-in.txt.gz", sep="\t")

productos_ok = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/product_id_apredecir201912.txt", sep="\t")

df = df[df["product_id"].isin(productos_ok["product_id"])]
periodos = df["periodo"].unique()

# ---------------------------------------------
# Agrupar productos en 5 quantiles según la desviación estándar de los últimos 6 meses:
# ---------------------------------------------
ultimos_6_meses = list(periodos[-6:])
std6 = df.query("periodo in @ultimos_6_meses").groupby("product_id")["tn"].std().reset_index().fillna(0)
std6.columns = ["product_id", "std6"]
std6.sort_values(by="std6", ascending=False, inplace=True)
std6["grupo"] = pd.qcut(std6["std6"], 5, labels=False)
productos = list(df["product_id"].unique())
productos.sort()
# Filtrar productos entre 50 y 150
max_std = std6["grupo"].max()
grupo_dict = {int(r.product_id): int(r.grupo) for i, r in std6.iterrows()}

# %%
# ---------------------------------------------
# Completar dataset con períodos faltantes:
# ---------------------------------------------

# Agrupar y sumar las toneladas por producto y período
df_grouped = df.groupby(["product_id", "periodo"]).agg({"tn": "sum"}).reset_index()


# Encontrar el primer período para cada producto
min_periods = df_grouped.groupby("product_id")["periodo"].min().reset_index()

# Crear todas las combinaciones relevantes
all_periods = df_grouped["periodo"].unique()
all_periods.sort()

# Usar un merge cartesiano con filtro posterior
df = (
    min_periods.merge(pd.DataFrame({"periodo": all_periods}), how="cross")
    .query("periodo_y >= periodo_x")
    .drop(columns="periodo_x")
    .rename(columns={"periodo_y": "periodo"})
    .merge(df_grouped, on=["product_id", "periodo"], how="left")
    .fillna(0)
    .sort_values(["product_id", "periodo"])
    .reset_index(drop=True)
)

# %%
# ---------------------------------------------
# Feature engineering opcional, en el modelo final no se usaron los features adicionales:
# ---------------------------------------------
# Agregación mensual por producto
df["periodo"] = pd.to_datetime(df["periodo"], format="%Y%m")

# Crear características por producto
def agregar_features(df):
    df = df.copy()
    df = df.sort_values(["product_id", "periodo"])
    # quantil de la desviación estándar de los últimos 6 meses
    df["grupo"] = df.product_id.map(grupo_dict).fillna(0)
    df["grupo"] = df["grupo"].astype(int)
    # Crear features con groupby + transform
    df["tn_lag1"] = df.groupby("product_id")["tn"].shift(1)


    df["tn_diff1"] = df["tn"] - df["tn_lag1"]

    
    df["sin_mes"] = df["periodo"].dt.month.apply(lambda x: np.sin(2 * np.pi * x / 12))
    df["quarter"] = df["periodo"].dt.quarter
    df["month"] = df["periodo"].dt.month

    df["rolling_mean6"] = df.groupby("product_id")["tn"].transform(lambda x: x.shift(1).rolling(6).mean())
    df["rolling_std6"] = df.groupby("product_id")["tn"].transform(lambda x: x.shift(1).rolling(6).std())

    return df

df_features = agregar_features(df).fillna(0)
df = df_features.copy()
print(df_features.shape)
# Out:
# (22375, 11)

# %%
df_features
# Out:
#        product_id    periodo          tn  grupo     tn_lag1   tn_diff1  \
# 0           20001 2017-01-01   934.77222      4     0.00000    0.00000
# 1           20001 2017-02-01   798.01620      4   934.77222 -136.75602
# 2           20001 2017-03-01  1303.35771      4   798.01620  505.34151
# 3           20001 2017-04-01  1069.96130      4  1303.35771 -233.39641
# 4           20001 2017-05-01  1502.20132      4  1069.96130  432.24002
# ...           ...        ...         ...    ...         ...        ...
# 22370       21276 2019-08-01     0.01265      0     0.00223    0.01042
# 22371       21276 2019-09-01     0.01856      0     0.01265    0.00591
# 22372       21276 2019-10-01     0.02079      0     0.01856    0.00223
# 22373       21276 2019-11-01     0.03341      0     0.02079    0.01262
# 22374       21276 2019-12-01     0.00892      0     0.03341   -0.02449
#
#             sin_mes  quarter  month  rolling_mean6  rolling_std6
# 0      5.000000e-01        1      1       0.000000      0.000000
# 1      8.660254e-01        1      2       0.000000      0.000000
# 2      1.000000e+00        1      3       0.000000      0.000000
# 3      8.660254e-01        2      4       0.000000      0.000000
# 4      5.000000e-01        2      5       0.000000      0.000000
# ...             ...      ...    ...            ...           ...
# 22370 -8.660254e-01        3      8       0.000000      0.000000
# 22371 -1.000000e+00        3      9       0.062132      0.050285
# 22372 -8.660254e-01        4     10       0.044810      0.042656
# 22373 -5.000000e-01        4     11       0.031320      0.032689
# 22374 -2.449294e-16        4     12       0.021417      0.013967
#
# [22375 rows x 11 columns]

# %%
# ---------------------------------------------
# Limipieza de periodos:
# ---------------------------------------------
# Último período disponible
ultimo_mes = df_features["periodo"].max()

# Definir los 3 meses anteriores
ultimos_3_meses = pd.date_range(end=ultimo_mes - pd.DateOffset(months=1), periods=3, freq='MS')

# Filtrar productos con datos en al menos 3 de esos meses
df_filtrado = df_features[df_features["periodo"].isin(ultimos_3_meses)]

# Contar cuántos meses tiene cada producto
conteo_por_producto = df_filtrado[df_filtrado["tn"] > 0].groupby("product_id").size()

# Seleccionar productos válidos
productos_validos = conteo_por_producto[conteo_por_producto >= 3].index

# Filtrar el dataframe original
df_features = df_features[df_features["product_id"].isin(productos_validos)].copy()
print(df_features.shape)
# Out:
# (22375, 11)

# %%
# ---------------------------------------------
# testeo diciembre 2019:
# ---------------------------------------------
df_test = df_features[df_features["periodo"] == pd.to_datetime(201912, format="%Y%m")].copy()
df_features[df_features["periodo"].isin(pd.to_datetime([201911, 201912], format="%Y%m")) ]
# Out:
#        product_id    periodo          tn  grupo     tn_lag1   tn_diff1  \
# 34          20001 2019-11-01  1397.37231      4  1561.50552 -164.13321
# 35          20001 2019-12-01  1504.68856      4  1397.37231  107.31625
# 70          20002 2019-11-01  1423.57739      4  1979.53635 -555.95896
# 71          20002 2019-12-01  1087.30855      4  1423.57739 -336.26884
# 106         20003 2019-11-01   948.29393      4  1081.36645 -133.07252
# ...           ...        ...         ...    ...         ...        ...
# 22354       21266 2019-12-01     0.05121      0     0.06713   -0.01592
# 22363       21267 2019-11-01     0.04052      0     0.09676   -0.05624
# 22364       21267 2019-12-01     0.01569      0     0.04052   -0.02483
# 22373       21276 2019-11-01     0.03341      0     0.02079    0.01262
# 22374       21276 2019-12-01     0.00892      0     0.03341   -0.02449
#
#             sin_mes  quarter  month  rolling_mean6  rolling_std6
# 34    -5.000000e-01        4     11    1483.594937    239.063446
# 35    -2.449294e-16        4     12    1444.859933    229.267460
# 70    -5.000000e-01        4     11    1152.218297    418.103201
# 71    -2.449294e-16        4     12    1216.982983    426.327986
# 106   -5.000000e-01        4     11     775.408012    200.444440
# ...             ...      ...    ...            ...           ...
# 22354 -2.449294e-16        4     12       0.056698      0.036011
# 22363 -5.000000e-01        4     11       0.088908      0.080884
# 22364 -2.449294e-16        4     12       0.054910      0.027947
# 22373 -5.000000e-01        4     11       0.031320      0.032689
# 22374 -2.449294e-16        4     12       0.021417      0.013967
#
# [1560 rows x 11 columns]

# %%
# ================================
# SCALING Y VENTANAS TEMPORALES
# ================================

window_size = config["window_size"]

def get_window_size(q):
  window_size = 3 if q >= 3 else 6
  return window_size

scaler_name = config["scaler_name"]
feature_cols = config["feature_cols"]

# Agrupar por producto
productos = df_features["product_id"].unique()
productos = list(productos)
scalers = {}  # Guardamos los scalers por producto

# %%
# ================================
# TRAIN / TEST SPLIT
# ================================
from sklearn.model_selection import train_test_split
grupos = df_features["grupo"].unique()
grupos.sort()
sets = {}
modelos = {}
metricas = {}
seed = config.get("seed", 42)
for grupo in grupos:
    window_size = get_window_size(grupo)
    df_grupo = df_features[df_features["grupo"] == grupo].copy()
    sets[grupo] = {}
    X, y, productos_list = [], [], []
    periodos = []
    productos_train = df_grupo["product_id"].unique()
    
    for producto in productos_train:
        df_prod = df_features[df_features["product_id"] == producto].copy()
        df_prod = df_prod.sort_values('periodo')
        if len(df_prod) < window_size + 2:
            continue

        scaler = StandardScaler() if scaler_name == "standard" else RobustScaler()
        scaled_features = scaler.fit_transform(df_prod[feature_cols])
        scalers[producto] = scaler

        for i in range(window_size, len(df_prod) - 2):
            X_window = scaled_features[i - window_size:i]
            y_target = scaled_features[i][0]  # TN target
            mes_ultimo_valor = df_prod.iloc[i - 1]["month"]  # el último mes dentro de la ventana
            quarter_ultimo_valor = df_prod.iloc[i - 1]["quarter"]
            mes_scaled = (mes_ultimo_valor - 1) / 11  # Normalizado a [0, 1]
            
            quarter_scaled = (quarter_ultimo_valor - 1) / 3  # quarter ∈ [0, 3]
            
                # Crear una feature adicional repetida en la ventana
            mes_feature = np.full((window_size, 1), mes_scaled)
            quarter_feature = np.full((window_size, 1), quarter_scaled)
            
            X_with_extra = np.concatenate([X_window, mes_feature, quarter_feature], axis=1)
            
            X.append(X_with_extra)
            y.append(y_target)
            productos_list.append(producto)
            periodo_target = df_prod.iloc[i + 2]["periodo"]
            periodos.append(periodo_target)
    

    
    
    X = np.array(X)
    y = np.array(y).reshape(-1, 1)
    productos_list = np.array(productos_list)
    periodos = np.array(periodos)

    # Ahora sí, aplicá las máscaras
    train_mask = periodos <= pd.to_datetime("2019-09-30")
    test_mask = periodos == pd.to_datetime("2019-10-01")

    X_train, X_test = X[train_mask], X[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]
    productos_test = productos_list[test_mask]
    
    sets[grupo]["X"] = X
    sets[grupo]["y"] = y
    sets[grupo]["X_train"] = X_train
    sets[grupo]["X_test"] = X_test
    sets[grupo]["y_train"] = y_train
    sets[grupo]["y_test"] = y_test
    sets[grupo]["productos_train"] = productos_train
    print(f"grupo {grupo}: {len(productos_train)} productos, {len(X_train)} muestras de entrenamiento, {len(X_test)} muestras de test")
    
    
    
# ================================
# Out:
# grupo 0: 156 productos, 2363 muestras de entrenamiento, 122 muestras de test
# grupo 1: 156 productos, 2947 muestras de entrenamiento, 132 muestras de test
# grupo 2: 156 productos, 2668 muestras de entrenamiento, 129 muestras de test
# grupo 3: 156 productos, 3362 muestras de entrenamiento, 149 muestras de test
# grupo 4: 156 productos, 3749 muestras de entrenamiento, 146 muestras de test

# %%
# ================================
# 4. MODELO LSTM
# ================================
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

tf.random.set_seed(seed)

def custom_mape_loss(y_true, y_pred):
    """
    Pérdida personalizada: Mean Absolute Percentage Error (MAPE) modificado
    donde el denominador es la suma total de los valores reales.
    """
    numerator = tf.reduce_sum(tf.abs(y_true - y_pred))
    denominator = tf.reduce_sum(tf.abs(y_true))
    return numerator / (denominator + tf.keras.backend.epsilon())  # Evita división por cero

for grupo in sets:
    window_size = get_window_size(grupo)
    set_data = sets[grupo]
    X_train = set_data["X_train"]
    y_train = set_data["y_train"]
    X_test = set_data["X_test"]
    y_test = set_data["y_test"]
    
    
    
    l2_lambda = config["l2_lambda"]
    optimizer = config["optimizer"]
    epochs = config["epochs"]
    batch_size = config["batch_size"]
    early_stopping_patience = config["early_stopping_patience"]

    def get_reg(l2_lambda):
        return l2(l2_lambda) if l2_lambda > 0 else None

    n_features = X_train.shape[2] 
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=(window_size, n_features)),
        Dropout(0.3),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(32, activation='relu', kernel_regularizer=get_reg(l2_lambda)),
        Dense(1)
    ])

    model.compile(optimizer=optimizer, loss=custom_mape_loss, metrics=custom_mape_loss)

    callbacks = [
         EarlyStopping(patience=early_stopping_patience, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.1, patience=15)
    ]

    model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test, y_test),
        callbacks=callbacks,
        verbose=1,
    )
    modelos[grupo] = model
    # Evaluar el modelo
    
    loss, mae = model.evaluate(X_test, y_test, verbose=0)
    metricas[grupo] = {
        "loss": loss,
        "mae": mae
    }
# Out:
# Epoch 1/150
# 37/37 [==============================] - 8s 64ms/step - loss: 1.0150 - custom_mape_loss: 0.9883 - val_loss: 0.9487 - val_custom_mape_loss: 0.9255 - lr: 0.0010
# Epoch 2/150
# 37/37 [==============================] - 1s 24ms/step - loss: 0.9834 - custom_mape_loss: 0.9612 - val_loss: 0.9091 - val_custom_mape_loss: 0.8904 - lr: 0.0010
# Epoch 3/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9608 - custom_mape_loss: 0.9415 - val_loss: 0.8800 - val_custom_mape_loss: 0.8654 - lr: 0.0010
# Epoch 4/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9489 - custom_mape_loss: 0.9312 - val_loss: 0.8677 - val_custom_mape_loss: 0.8548 - lr: 0.0010
# Epoch 5/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9401 - custom_mape_loss: 0.9239 - val_loss: 0.9127 - val_custom_mape_loss: 0.9020 - lr: 0.0010
# Epoch 6/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9294 - custom_mape_loss: 0.9141 - val_loss: 0.8474 - val_custom_mape_loss: 0.8383 - lr: 0.0010
# Epoch 7/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9279 - custom_mape_loss: 0.9136 - val_loss: 0.8370 - val_custom_mape_loss: 0.8287 - lr: 0.0010
# Epoch 8/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9245 - custom_mape_loss: 0.9109 - val_loss: 0.8999 - val_custom_mape_loss: 0.8922 - lr: 0.0010
# Epoch 9/150
# 37/37 [==============================] - 1s 24ms/step - loss: 0.9182 - custom_mape_loss: 0.9051 - val_loss: 0.8479 - val_custom_mape_loss: 0.8404 - lr: 0.0010
# Epoch 10/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9229 - custom_mape_loss: 0.9101 - val_loss: 0.9344 - val_custom_mape_loss: 0.9285 - lr: 0.0010
# Epoch 11/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.9206 - custom_mape_loss: 0.9081 - val_loss: 0.8543 - val_custom_mape_loss: 0.8486 - lr: 0.0010
# Epoch 12/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9182 - custom_mape_loss: 0.9061 - val_loss: 0.8571 - val_custom_mape_loss: 0.8512 - lr: 0.0010
# Epoch 13/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9150 - custom_mape_loss: 0.9034 - val_loss: 0.8978 - val_custom_mape_loss: 0.8918 - lr: 0.0010
# Epoch 14/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.9145 - custom_mape_loss: 0.9031 - val_loss: 0.9032 - val_custom_mape_loss: 0.8978 - lr: 0.0010
# Epoch 15/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9142 - custom_mape_loss: 0.9032 - val_loss: 0.8635 - val_custom_mape_loss: 0.8587 - lr: 0.0010
# Epoch 16/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.9129 - custom_mape_loss: 0.9024 - val_loss: 0.9195 - val_custom_mape_loss: 0.9141 - lr: 0.0010
# Epoch 17/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9064 - custom_mape_loss: 0.8959 - val_loss: 0.8957 - val_custom_mape_loss: 0.8933 - lr: 0.0010
# Epoch 18/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9110 - custom_mape_loss: 0.9010 - val_loss: 0.8858 - val_custom_mape_loss: 0.8820 - lr: 0.0010
# Epoch 19/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9103 - custom_mape_loss: 0.9005 - val_loss: 0.8760 - val_custom_mape_loss: 0.8740 - lr: 0.0010
# Epoch 20/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9072 - custom_mape_loss: 0.8977 - val_loss: 0.9377 - val_custom_mape_loss: 0.9352 - lr: 0.0010
# Epoch 21/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.9028 - custom_mape_loss: 0.8935 - val_loss: 0.8307 - val_custom_mape_loss: 0.8294 - lr: 0.0010
# Epoch 22/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.9022 - custom_mape_loss: 0.8930 - val_loss: 0.9682 - val_custom_mape_loss: 0.9647 - lr: 0.0010
# Epoch 23/150
# 37/37 [==============================] - 1s 24ms/step - loss: 0.8954 - custom_mape_loss: 0.8864 - val_loss: 0.9218 - val_custom_mape_loss: 0.9185 - lr: 0.0010
# Epoch 24/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8980 - custom_mape_loss: 0.8891 - val_loss: 0.9180 - val_custom_mape_loss: 0.9160 - lr: 0.0010
# Epoch 25/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8978 - custom_mape_loss: 0.8890 - val_loss: 0.8644 - val_custom_mape_loss: 0.8620 - lr: 0.0010
# Epoch 26/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8945 - custom_mape_loss: 0.8860 - val_loss: 0.8682 - val_custom_mape_loss: 0.8663 - lr: 0.0010
# Epoch 27/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8947 - custom_mape_loss: 0.8863 - val_loss: 0.8952 - val_custom_mape_loss: 0.8936 - lr: 0.0010
# Epoch 28/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8902 - custom_mape_loss: 0.8818 - val_loss: 0.9090 - val_custom_mape_loss: 0.9105 - lr: 0.0010
# Epoch 29/150
# 37/37 [==============================] - 1s 24ms/step - loss: 0.8912 - custom_mape_loss: 0.8831 - val_loss: 0.8555 - val_custom_mape_loss: 0.8554 - lr: 0.0010
# Epoch 30/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8883 - custom_mape_loss: 0.8804 - val_loss: 0.9231 - val_custom_mape_loss: 0.9238 - lr: 0.0010
# Epoch 31/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8890 - custom_mape_loss: 0.8812 - val_loss: 0.8900 - val_custom_mape_loss: 0.8906 - lr: 0.0010
# Epoch 32/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8915 - custom_mape_loss: 0.8837 - val_loss: 0.8974 - val_custom_mape_loss: 0.8974 - lr: 0.0010
# Epoch 33/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8844 - custom_mape_loss: 0.8767 - val_loss: 0.8683 - val_custom_mape_loss: 0.8675 - lr: 0.0010
# Epoch 34/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8855 - custom_mape_loss: 0.8780 - val_loss: 0.9723 - val_custom_mape_loss: 0.9723 - lr: 0.0010
# Epoch 35/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8896 - custom_mape_loss: 0.8822 - val_loss: 1.0639 - val_custom_mape_loss: 1.0645 - lr: 0.0010
# Epoch 36/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8864 - custom_mape_loss: 0.8795 - val_loss: 0.9126 - val_custom_mape_loss: 0.9120 - lr: 0.0010
# Epoch 37/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8722 - custom_mape_loss: 0.8650 - val_loss: 0.9061 - val_custom_mape_loss: 0.9063 - lr: 1.0000e-04
# Epoch 38/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8738 - custom_mape_loss: 0.8664 - val_loss: 0.9181 - val_custom_mape_loss: 0.9188 - lr: 1.0000e-04
# Epoch 39/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8688 - custom_mape_loss: 0.8616 - val_loss: 0.9230 - val_custom_mape_loss: 0.9237 - lr: 1.0000e-04
# Epoch 40/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8689 - custom_mape_loss: 0.8620 - val_loss: 0.9113 - val_custom_mape_loss: 0.9121 - lr: 1.0000e-04
# Epoch 41/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8689 - custom_mape_loss: 0.8617 - val_loss: 0.9072 - val_custom_mape_loss: 0.9082 - lr: 1.0000e-04
# Epoch 42/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8698 - custom_mape_loss: 0.8625 - val_loss: 0.9088 - val_custom_mape_loss: 0.9097 - lr: 1.0000e-04
# Epoch 43/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8681 - custom_mape_loss: 0.8611 - val_loss: 0.9227 - val_custom_mape_loss: 0.9237 - lr: 1.0000e-04
# Epoch 44/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8682 - custom_mape_loss: 0.8612 - val_loss: 0.9199 - val_custom_mape_loss: 0.9207 - lr: 1.0000e-04
# Epoch 45/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8667 - custom_mape_loss: 0.8595 - val_loss: 0.9427 - val_custom_mape_loss: 0.9438 - lr: 1.0000e-04
# Epoch 46/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8668 - custom_mape_loss: 0.8596 - val_loss: 0.9242 - val_custom_mape_loss: 0.9253 - lr: 1.0000e-04
# Epoch 47/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8712 - custom_mape_loss: 0.8641 - val_loss: 0.9205 - val_custom_mape_loss: 0.9216 - lr: 1.0000e-04
# Epoch 48/150
# 37/37 [==============================] - 1s 22ms/step - loss: 0.8665 - custom_mape_loss: 0.8594 - val_loss: 0.9166 - val_custom_mape_loss: 0.9176 - lr: 1.0000e-04
# Epoch 49/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8686 - custom_mape_loss: 0.8617 - val_loss: 0.9280 - val_custom_mape_loss: 0.9291 - lr: 1.0000e-04
# Epoch 50/150
# 37/37 [==============================] - 1s 23ms/step - loss: 0.8671 - custom_mape_loss: 0.8599 - val_loss: 0.9181 - val_custom_mape_loss: 0.9193 - lr: 1.0000e-04
# Epoch 51/150
# 37/37 [==============================] - 1s 24ms/step - loss: 0.8641 - custom_mape_loss: 0.8569 - val_loss: 0.9216 - val_custom_mape_loss: 0.9230 - lr: 1.0000e-04
# Epoch 1/150
# 47/47 [==============================] - 8s 53ms/step - loss: 1.0088 - custom_mape_loss: 0.9790 - val_loss: 0.8642 - val_custom_mape_loss: 0.8569 - lr: 0.0010
# Epoch 2/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.9777 - custom_mape_loss: 0.9546 - val_loss: 0.9887 - val_custom_mape_loss: 1.0083 - lr: 0.0010
# Epoch 3/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9563 - custom_mape_loss: 0.9417 - val_loss: 0.9426 - val_custom_mape_loss: 0.9737 - lr: 0.0010
# Epoch 4/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9389 - custom_mape_loss: 0.9287 - val_loss: 1.0414 - val_custom_mape_loss: 1.0944 - lr: 0.0010
# Epoch 5/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9277 - custom_mape_loss: 0.9145 - val_loss: 1.0601 - val_custom_mape_loss: 1.1316 - lr: 0.0010
# Epoch 6/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9240 - custom_mape_loss: 0.8987 - val_loss: 1.1323 - val_custom_mape_loss: 1.2349 - lr: 0.0010
# Epoch 7/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.9200 - custom_mape_loss: 0.9097 - val_loss: 0.6873 - val_custom_mape_loss: 0.7342 - lr: 0.0010
# Epoch 8/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9141 - custom_mape_loss: 0.9009 - val_loss: 0.6590 - val_custom_mape_loss: 0.6631 - lr: 0.0010
# Epoch 9/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.9174 - custom_mape_loss: 0.9057 - val_loss: 0.8412 - val_custom_mape_loss: 0.9492 - lr: 0.0010
# Epoch 10/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9111 - custom_mape_loss: 0.9035 - val_loss: 1.1855 - val_custom_mape_loss: 1.3107 - lr: 0.0010
# Epoch 11/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9100 - custom_mape_loss: 0.9062 - val_loss: 0.8678 - val_custom_mape_loss: 0.9319 - lr: 0.0010
# Epoch 12/150
# 47/47 [==============================] - 1s 21ms/step - loss: 0.9077 - custom_mape_loss: 0.8952 - val_loss: 0.7673 - val_custom_mape_loss: 0.8280 - lr: 0.0010
# Epoch 13/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9046 - custom_mape_loss: 0.8893 - val_loss: 0.9863 - val_custom_mape_loss: 1.1196 - lr: 0.0010
# Epoch 14/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9037 - custom_mape_loss: 0.8921 - val_loss: 0.7351 - val_custom_mape_loss: 0.8017 - lr: 0.0010
# Epoch 15/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.9013 - custom_mape_loss: 0.8833 - val_loss: 0.7897 - val_custom_mape_loss: 0.8807 - lr: 0.0010
# Epoch 16/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.9003 - custom_mape_loss: 0.9045 - val_loss: 0.7717 - val_custom_mape_loss: 0.8495 - lr: 0.0010
# Epoch 17/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.9013 - custom_mape_loss: 0.8936 - val_loss: 0.9287 - val_custom_mape_loss: 1.0255 - lr: 0.0010
# Epoch 18/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8965 - custom_mape_loss: 0.8836 - val_loss: 0.6808 - val_custom_mape_loss: 0.7180 - lr: 0.0010
# Epoch 19/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8969 - custom_mape_loss: 0.8922 - val_loss: 0.8939 - val_custom_mape_loss: 1.0116 - lr: 0.0010
# Epoch 20/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8935 - custom_mape_loss: 0.8767 - val_loss: 0.9129 - val_custom_mape_loss: 1.0025 - lr: 0.0010
# Epoch 21/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8923 - custom_mape_loss: 0.8853 - val_loss: 0.9020 - val_custom_mape_loss: 1.0367 - lr: 0.0010
# Epoch 22/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8943 - custom_mape_loss: 0.9022 - val_loss: 1.0260 - val_custom_mape_loss: 1.1258 - lr: 0.0010
# Epoch 23/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8903 - custom_mape_loss: 0.8964 - val_loss: 0.8623 - val_custom_mape_loss: 0.9463 - lr: 0.0010
# Epoch 24/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8863 - custom_mape_loss: 0.8789 - val_loss: 0.8711 - val_custom_mape_loss: 0.9740 - lr: 1.0000e-04
# Epoch 25/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8799 - custom_mape_loss: 0.8679 - val_loss: 0.8680 - val_custom_mape_loss: 0.9716 - lr: 1.0000e-04
# Epoch 26/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8779 - custom_mape_loss: 0.8699 - val_loss: 0.8604 - val_custom_mape_loss: 0.9669 - lr: 1.0000e-04
# Epoch 27/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8802 - custom_mape_loss: 0.8703 - val_loss: 0.8652 - val_custom_mape_loss: 0.9784 - lr: 1.0000e-04
# Epoch 28/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8798 - custom_mape_loss: 0.8831 - val_loss: 0.8741 - val_custom_mape_loss: 0.9902 - lr: 1.0000e-04
# Epoch 29/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8777 - custom_mape_loss: 0.8675 - val_loss: 0.8842 - val_custom_mape_loss: 1.0017 - lr: 1.0000e-04
# Epoch 30/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8772 - custom_mape_loss: 0.8647 - val_loss: 0.8729 - val_custom_mape_loss: 0.9909 - lr: 1.0000e-04
# Epoch 31/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8795 - custom_mape_loss: 0.8692 - val_loss: 0.8759 - val_custom_mape_loss: 0.9889 - lr: 1.0000e-04
# Epoch 32/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8778 - custom_mape_loss: 0.8732 - val_loss: 0.8669 - val_custom_mape_loss: 0.9805 - lr: 1.0000e-04
# Epoch 33/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8762 - custom_mape_loss: 0.8679 - val_loss: 0.8654 - val_custom_mape_loss: 0.9801 - lr: 1.0000e-04
# Epoch 34/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8747 - custom_mape_loss: 0.8696 - val_loss: 0.8794 - val_custom_mape_loss: 0.9969 - lr: 1.0000e-04
# Epoch 35/150
# 47/47 [==============================] - 1s 23ms/step - loss: 0.8774 - custom_mape_loss: 0.8691 - val_loss: 0.8698 - val_custom_mape_loss: 0.9902 - lr: 1.0000e-04
# Epoch 36/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8803 - custom_mape_loss: 0.8760 - val_loss: 0.8884 - val_custom_mape_loss: 1.0052 - lr: 1.0000e-04
# Epoch 37/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8751 - custom_mape_loss: 0.8696 - val_loss: 0.8759 - val_custom_mape_loss: 0.9947 - lr: 1.0000e-04
# Epoch 38/150
# 47/47 [==============================] - 1s 22ms/step - loss: 0.8734 - custom_mape_loss: 0.8685 - val_loss: 0.8487 - val_custom_mape_loss: 0.9593 - lr: 1.0000e-04
# Epoch 1/150
# 42/42 [==============================] - 7s 57ms/step - loss: 1.0155 - custom_mape_loss: 0.9873 - val_loss: 0.8305 - val_custom_mape_loss: 0.8800 - lr: 0.0010
# Epoch 2/150
# 42/42 [==============================] - 1s 24ms/step - loss: 0.9951 - custom_mape_loss: 0.9724 - val_loss: 0.9454 - val_custom_mape_loss: 0.9549 - lr: 0.0010
# Epoch 3/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9728 - custom_mape_loss: 0.9533 - val_loss: 0.8224 - val_custom_mape_loss: 0.8804 - lr: 0.0010
# Epoch 4/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9557 - custom_mape_loss: 0.9383 - val_loss: 1.1191 - val_custom_mape_loss: 1.0651 - lr: 0.0010
# Epoch 5/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9488 - custom_mape_loss: 0.9328 - val_loss: 0.8553 - val_custom_mape_loss: 0.8963 - lr: 0.0010
# Epoch 6/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9375 - custom_mape_loss: 0.9220 - val_loss: 0.8942 - val_custom_mape_loss: 0.9197 - lr: 0.0010
# Epoch 7/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9342 - custom_mape_loss: 0.9202 - val_loss: 0.7925 - val_custom_mape_loss: 0.8576 - lr: 0.0010
# Epoch 8/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9285 - custom_mape_loss: 0.9156 - val_loss: 0.8932 - val_custom_mape_loss: 0.9187 - lr: 0.0010
# Epoch 9/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9280 - custom_mape_loss: 0.9149 - val_loss: 0.9133 - val_custom_mape_loss: 0.9343 - lr: 0.0010
# Epoch 10/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9279 - custom_mape_loss: 0.9164 - val_loss: 0.9010 - val_custom_mape_loss: 0.9248 - lr: 0.0010
# Epoch 11/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9208 - custom_mape_loss: 0.9090 - val_loss: 0.9017 - val_custom_mape_loss: 0.9254 - lr: 0.0010
# Epoch 12/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9192 - custom_mape_loss: 0.9086 - val_loss: 0.8105 - val_custom_mape_loss: 0.8686 - lr: 0.0010
# Epoch 13/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9181 - custom_mape_loss: 0.9078 - val_loss: 0.9546 - val_custom_mape_loss: 0.9528 - lr: 0.0010
# Epoch 14/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9144 - custom_mape_loss: 0.9043 - val_loss: 0.8766 - val_custom_mape_loss: 0.9053 - lr: 0.0010
# Epoch 15/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9143 - custom_mape_loss: 0.9052 - val_loss: 0.8156 - val_custom_mape_loss: 0.8669 - lr: 0.0010
# Epoch 16/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9117 - custom_mape_loss: 0.9014 - val_loss: 0.7572 - val_custom_mape_loss: 0.8332 - lr: 0.0010
# Epoch 17/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9062 - custom_mape_loss: 0.8972 - val_loss: 0.8264 - val_custom_mape_loss: 0.8734 - lr: 0.0010
# Epoch 18/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9077 - custom_mape_loss: 0.8981 - val_loss: 0.8603 - val_custom_mape_loss: 0.8930 - lr: 0.0010
# Epoch 19/150
# 42/42 [==============================] - 1s 24ms/step - loss: 0.9045 - custom_mape_loss: 0.8957 - val_loss: 0.8894 - val_custom_mape_loss: 0.9164 - lr: 0.0010
# Epoch 20/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.9037 - custom_mape_loss: 0.8948 - val_loss: 0.8359 - val_custom_mape_loss: 0.8748 - lr: 0.0010
# Epoch 21/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.9022 - custom_mape_loss: 0.8938 - val_loss: 0.8909 - val_custom_mape_loss: 0.9103 - lr: 0.0010
# Epoch 22/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8965 - custom_mape_loss: 0.8885 - val_loss: 0.8547 - val_custom_mape_loss: 0.8926 - lr: 0.0010
# Epoch 23/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8995 - custom_mape_loss: 0.8918 - val_loss: 0.9799 - val_custom_mape_loss: 0.9658 - lr: 0.0010
# Epoch 24/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8981 - custom_mape_loss: 0.8904 - val_loss: 0.9991 - val_custom_mape_loss: 0.9754 - lr: 0.0010
# Epoch 25/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8946 - custom_mape_loss: 0.8870 - val_loss: 0.8607 - val_custom_mape_loss: 0.8938 - lr: 0.0010
# Epoch 26/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8929 - custom_mape_loss: 0.8856 - val_loss: 1.0092 - val_custom_mape_loss: 0.9843 - lr: 0.0010
# Epoch 27/150
# 42/42 [==============================] - 1s 24ms/step - loss: 0.8926 - custom_mape_loss: 0.8859 - val_loss: 1.0120 - val_custom_mape_loss: 0.9833 - lr: 0.0010
# Epoch 28/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8896 - custom_mape_loss: 0.8826 - val_loss: 1.0451 - val_custom_mape_loss: 1.0053 - lr: 0.0010
# Epoch 29/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8899 - custom_mape_loss: 0.8832 - val_loss: 1.0517 - val_custom_mape_loss: 1.0012 - lr: 0.0010
# Epoch 30/150
# 42/42 [==============================] - 1s 21ms/step - loss: 0.8863 - custom_mape_loss: 0.8802 - val_loss: 1.1246 - val_custom_mape_loss: 1.0528 - lr: 0.0010
# Epoch 31/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8805 - custom_mape_loss: 0.8738 - val_loss: 0.9127 - val_custom_mape_loss: 0.9178 - lr: 0.0010
# Epoch 32/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8757 - custom_mape_loss: 0.8690 - val_loss: 0.9299 - val_custom_mape_loss: 0.9345 - lr: 1.0000e-04
# Epoch 33/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8730 - custom_mape_loss: 0.8659 - val_loss: 0.9591 - val_custom_mape_loss: 0.9526 - lr: 1.0000e-04
# Epoch 34/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8748 - custom_mape_loss: 0.8688 - val_loss: 0.9620 - val_custom_mape_loss: 0.9542 - lr: 1.0000e-04
# Epoch 35/150
# 42/42 [==============================] - 1s 24ms/step - loss: 0.8718 - custom_mape_loss: 0.8648 - val_loss: 0.9670 - val_custom_mape_loss: 0.9559 - lr: 1.0000e-04
# Epoch 36/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8686 - custom_mape_loss: 0.8622 - val_loss: 0.9519 - val_custom_mape_loss: 0.9473 - lr: 1.0000e-04
# Epoch 37/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8674 - custom_mape_loss: 0.8605 - val_loss: 0.9730 - val_custom_mape_loss: 0.9597 - lr: 1.0000e-04
# Epoch 38/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8712 - custom_mape_loss: 0.8647 - val_loss: 0.9880 - val_custom_mape_loss: 0.9704 - lr: 1.0000e-04
# Epoch 39/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8697 - custom_mape_loss: 0.8632 - val_loss: 0.9981 - val_custom_mape_loss: 0.9760 - lr: 1.0000e-04
# Epoch 40/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8703 - custom_mape_loss: 0.8634 - val_loss: 0.9773 - val_custom_mape_loss: 0.9640 - lr: 1.0000e-04
# Epoch 41/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8724 - custom_mape_loss: 0.8662 - val_loss: 0.9871 - val_custom_mape_loss: 0.9691 - lr: 1.0000e-04
# Epoch 42/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8697 - custom_mape_loss: 0.8636 - val_loss: 0.9935 - val_custom_mape_loss: 0.9730 - lr: 1.0000e-04
# Epoch 43/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8690 - custom_mape_loss: 0.8625 - val_loss: 0.9787 - val_custom_mape_loss: 0.9656 - lr: 1.0000e-04
# Epoch 44/150
# 42/42 [==============================] - 1s 22ms/step - loss: 0.8681 - custom_mape_loss: 0.8614 - val_loss: 0.9895 - val_custom_mape_loss: 0.9709 - lr: 1.0000e-04
# Epoch 45/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8705 - custom_mape_loss: 0.8646 - val_loss: 0.9577 - val_custom_mape_loss: 0.9530 - lr: 1.0000e-04
# Epoch 46/150
# 42/42 [==============================] - 1s 23ms/step - loss: 0.8682 - custom_mape_loss: 0.8615 - val_loss: 0.9684 - val_custom_mape_loss: 0.9596 - lr: 1.0000e-04
# Epoch 1/150
# 53/53 [==============================] - 8s 49ms/step - loss: 1.0033 - custom_mape_loss: 0.9779 - val_loss: 0.9672 - val_custom_mape_loss: 0.9490 - lr: 0.0010
# Epoch 2/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9794 - custom_mape_loss: 0.9597 - val_loss: 0.9972 - val_custom_mape_loss: 0.9852 - lr: 0.0010
# Epoch 3/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9673 - custom_mape_loss: 0.9510 - val_loss: 0.9471 - val_custom_mape_loss: 0.9357 - lr: 0.0010
# Epoch 4/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9560 - custom_mape_loss: 0.9424 - val_loss: 0.8332 - val_custom_mape_loss: 0.8076 - lr: 0.0010
# Epoch 5/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9531 - custom_mape_loss: 0.9419 - val_loss: 0.9481 - val_custom_mape_loss: 0.9468 - lr: 0.0010
# Epoch 6/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9470 - custom_mape_loss: 0.9375 - val_loss: 1.0568 - val_custom_mape_loss: 1.0723 - lr: 0.0010
# Epoch 7/150
# 53/53 [==============================] - 1s 22ms/step - loss: 0.9457 - custom_mape_loss: 0.9362 - val_loss: 0.9326 - val_custom_mape_loss: 0.9240 - lr: 0.0010
# Epoch 8/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9464 - custom_mape_loss: 0.9378 - val_loss: 1.0054 - val_custom_mape_loss: 1.0161 - lr: 0.0010
# Epoch 9/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9447 - custom_mape_loss: 0.9371 - val_loss: 1.0028 - val_custom_mape_loss: 1.0110 - lr: 0.0010
# Epoch 10/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9439 - custom_mape_loss: 0.9383 - val_loss: 0.9338 - val_custom_mape_loss: 0.9320 - lr: 0.0010
# Epoch 11/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9427 - custom_mape_loss: 0.9362 - val_loss: 0.9764 - val_custom_mape_loss: 0.9820 - lr: 0.0010
# Epoch 12/150
# 53/53 [==============================] - 1s 22ms/step - loss: 0.9422 - custom_mape_loss: 0.9347 - val_loss: 0.9415 - val_custom_mape_loss: 0.9401 - lr: 0.0010
# Epoch 13/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9396 - custom_mape_loss: 0.9340 - val_loss: 0.9712 - val_custom_mape_loss: 0.9787 - lr: 0.0010
# Epoch 14/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9413 - custom_mape_loss: 0.9362 - val_loss: 0.9507 - val_custom_mape_loss: 0.9523 - lr: 0.0010
# Epoch 15/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9400 - custom_mape_loss: 0.9362 - val_loss: 1.0171 - val_custom_mape_loss: 1.0292 - lr: 0.0010
# Epoch 16/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9381 - custom_mape_loss: 0.9346 - val_loss: 0.9896 - val_custom_mape_loss: 0.9988 - lr: 0.0010
# Epoch 17/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9366 - custom_mape_loss: 0.9322 - val_loss: 0.9319 - val_custom_mape_loss: 0.9306 - lr: 0.0010
# Epoch 18/150
# 53/53 [==============================] - 1s 22ms/step - loss: 0.9345 - custom_mape_loss: 0.9301 - val_loss: 0.9805 - val_custom_mape_loss: 0.9897 - lr: 0.0010
# Epoch 19/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9347 - custom_mape_loss: 0.9304 - val_loss: 0.9850 - val_custom_mape_loss: 0.9906 - lr: 0.0010
# Epoch 20/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9322 - custom_mape_loss: 0.9288 - val_loss: 0.9833 - val_custom_mape_loss: 0.9905 - lr: 1.0000e-04
# Epoch 21/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9330 - custom_mape_loss: 0.9280 - val_loss: 0.9762 - val_custom_mape_loss: 0.9834 - lr: 1.0000e-04
# Epoch 22/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9285 - custom_mape_loss: 0.9249 - val_loss: 0.9885 - val_custom_mape_loss: 0.9987 - lr: 1.0000e-04
# Epoch 23/150
# 53/53 [==============================] - 1s 22ms/step - loss: 0.9300 - custom_mape_loss: 0.9261 - val_loss: 0.9833 - val_custom_mape_loss: 0.9931 - lr: 1.0000e-04
# Epoch 24/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9300 - custom_mape_loss: 0.9247 - val_loss: 0.9801 - val_custom_mape_loss: 0.9893 - lr: 1.0000e-04
# Epoch 25/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9285 - custom_mape_loss: 0.9247 - val_loss: 0.9782 - val_custom_mape_loss: 0.9871 - lr: 1.0000e-04
# Epoch 26/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9294 - custom_mape_loss: 0.9255 - val_loss: 0.9763 - val_custom_mape_loss: 0.9851 - lr: 1.0000e-04
# Epoch 27/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9295 - custom_mape_loss: 0.9270 - val_loss: 0.9948 - val_custom_mape_loss: 1.0073 - lr: 1.0000e-04
# Epoch 28/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9311 - custom_mape_loss: 0.9276 - val_loss: 0.9854 - val_custom_mape_loss: 0.9961 - lr: 1.0000e-04
# Epoch 29/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9281 - custom_mape_loss: 0.9234 - val_loss: 0.9827 - val_custom_mape_loss: 0.9929 - lr: 1.0000e-04
# Epoch 30/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9273 - custom_mape_loss: 0.9225 - val_loss: 0.9885 - val_custom_mape_loss: 1.0000 - lr: 1.0000e-04
# Epoch 31/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9279 - custom_mape_loss: 0.9246 - val_loss: 0.9874 - val_custom_mape_loss: 0.9988 - lr: 1.0000e-04
# Epoch 32/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9294 - custom_mape_loss: 0.9261 - val_loss: 0.9922 - val_custom_mape_loss: 1.0047 - lr: 1.0000e-04
# Epoch 33/150
# 53/53 [==============================] - 1s 21ms/step - loss: 0.9291 - custom_mape_loss: 0.9259 - val_loss: 0.9874 - val_custom_mape_loss: 0.9988 - lr: 1.0000e-04
# Epoch 34/150
# 53/53 [==============================] - 1s 22ms/step - loss: 0.9283 - custom_mape_loss: 0.9245 - val_loss: 0.9894 - val_custom_mape_loss: 1.0014 - lr: 1.0000e-04
# Epoch 1/150
# 59/59 [==============================] - 8s 46ms/step - loss: 0.9910 - custom_mape_loss: 0.9655 - val_loss: 0.9907 - val_custom_mape_loss: 0.9790 - lr: 0.0010
# Epoch 2/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9679 - custom_mape_loss: 0.9491 - val_loss: 0.9169 - val_custom_mape_loss: 0.9181 - lr: 0.0010
# Epoch 3/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9514 - custom_mape_loss: 0.9363 - val_loss: 0.9763 - val_custom_mape_loss: 0.9862 - lr: 0.0010
# Epoch 4/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9391 - custom_mape_loss: 0.9261 - val_loss: 0.8847 - val_custom_mape_loss: 0.9017 - lr: 0.0010
# Epoch 5/150
# 59/59 [==============================] - 1s 22ms/step - loss: 0.9332 - custom_mape_loss: 0.9215 - val_loss: 0.9916 - val_custom_mape_loss: 1.0052 - lr: 0.0010
# Epoch 6/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9320 - custom_mape_loss: 0.9207 - val_loss: 0.9615 - val_custom_mape_loss: 0.9782 - lr: 0.0010
# Epoch 7/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9307 - custom_mape_loss: 0.9212 - val_loss: 0.8513 - val_custom_mape_loss: 0.8776 - lr: 0.0010
# Epoch 8/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9285 - custom_mape_loss: 0.9182 - val_loss: 0.9141 - val_custom_mape_loss: 0.9434 - lr: 0.0010
# Epoch 9/150
# 59/59 [==============================] - 1s 22ms/step - loss: 0.9294 - custom_mape_loss: 0.9214 - val_loss: 0.8731 - val_custom_mape_loss: 0.8976 - lr: 0.0010
# Epoch 10/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9266 - custom_mape_loss: 0.9185 - val_loss: 0.9809 - val_custom_mape_loss: 1.0034 - lr: 0.0010
# Epoch 11/150
# 59/59 [==============================] - 1s 20ms/step - loss: 0.9253 - custom_mape_loss: 0.9192 - val_loss: 0.9817 - val_custom_mape_loss: 1.0018 - lr: 0.0010
# Epoch 12/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9248 - custom_mape_loss: 0.9182 - val_loss: 0.9076 - val_custom_mape_loss: 0.9292 - lr: 0.0010
# Epoch 13/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9216 - custom_mape_loss: 0.9156 - val_loss: 0.9144 - val_custom_mape_loss: 0.9409 - lr: 0.0010
# Epoch 14/150
# 59/59 [==============================] - 1s 22ms/step - loss: 0.9183 - custom_mape_loss: 0.9121 - val_loss: 0.9275 - val_custom_mape_loss: 0.9681 - lr: 0.0010
# Epoch 15/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9216 - custom_mape_loss: 0.9160 - val_loss: 0.9190 - val_custom_mape_loss: 0.9482 - lr: 0.0010
# Epoch 16/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9191 - custom_mape_loss: 0.9136 - val_loss: 0.8799 - val_custom_mape_loss: 0.9067 - lr: 0.0010
# Epoch 17/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9182 - custom_mape_loss: 0.9128 - val_loss: 0.9466 - val_custom_mape_loss: 0.9794 - lr: 0.0010
# Epoch 18/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9147 - custom_mape_loss: 0.9099 - val_loss: 0.9106 - val_custom_mape_loss: 0.9399 - lr: 0.0010
# Epoch 19/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9168 - custom_mape_loss: 0.9116 - val_loss: 0.9071 - val_custom_mape_loss: 0.9475 - lr: 0.0010
# Epoch 20/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9139 - custom_mape_loss: 0.9098 - val_loss: 0.9366 - val_custom_mape_loss: 0.9641 - lr: 0.0010
# Epoch 21/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9077 - custom_mape_loss: 0.9036 - val_loss: 0.9750 - val_custom_mape_loss: 1.0052 - lr: 0.0010
# Epoch 22/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9099 - custom_mape_loss: 0.9056 - val_loss: 0.9637 - val_custom_mape_loss: 0.9980 - lr: 0.0010
# Epoch 23/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9043 - custom_mape_loss: 0.8998 - val_loss: 1.0114 - val_custom_mape_loss: 1.0485 - lr: 1.0000e-04
# Epoch 24/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9012 - custom_mape_loss: 0.8970 - val_loss: 1.0141 - val_custom_mape_loss: 1.0528 - lr: 1.0000e-04
# Epoch 25/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.9013 - custom_mape_loss: 0.8974 - val_loss: 1.0155 - val_custom_mape_loss: 1.0541 - lr: 1.0000e-04
# Epoch 26/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8995 - custom_mape_loss: 0.8950 - val_loss: 1.0148 - val_custom_mape_loss: 1.0536 - lr: 1.0000e-04
# Epoch 27/150
# 59/59 [==============================] - 1s 20ms/step - loss: 0.9008 - custom_mape_loss: 0.8965 - val_loss: 1.0184 - val_custom_mape_loss: 1.0573 - lr: 1.0000e-04
# Epoch 28/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8995 - custom_mape_loss: 0.8950 - val_loss: 1.0065 - val_custom_mape_loss: 1.0452 - lr: 1.0000e-04
# Epoch 29/150
# 59/59 [==============================] - 1s 22ms/step - loss: 0.9009 - custom_mape_loss: 0.8971 - val_loss: 1.0093 - val_custom_mape_loss: 1.0489 - lr: 1.0000e-04
# Epoch 30/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8984 - custom_mape_loss: 0.8942 - val_loss: 1.0343 - val_custom_mape_loss: 1.0728 - lr: 1.0000e-04
# Epoch 31/150
# 59/59 [==============================] - 1s 22ms/step - loss: 0.8971 - custom_mape_loss: 0.8927 - val_loss: 1.0246 - val_custom_mape_loss: 1.0646 - lr: 1.0000e-04
# Epoch 32/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8973 - custom_mape_loss: 0.8930 - val_loss: 1.0307 - val_custom_mape_loss: 1.0704 - lr: 1.0000e-04
# Epoch 33/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8985 - custom_mape_loss: 0.8940 - val_loss: 1.0389 - val_custom_mape_loss: 1.0774 - lr: 1.0000e-04
# Epoch 34/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8962 - custom_mape_loss: 0.8915 - val_loss: 1.0633 - val_custom_mape_loss: 1.1009 - lr: 1.0000e-04
# Epoch 35/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8979 - custom_mape_loss: 0.8934 - val_loss: 1.0389 - val_custom_mape_loss: 1.0779 - lr: 1.0000e-04
# Epoch 36/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8952 - custom_mape_loss: 0.8913 - val_loss: 1.0397 - val_custom_mape_loss: 1.0775 - lr: 1.0000e-04
# Epoch 37/150
# 59/59 [==============================] - 1s 21ms/step - loss: 0.8957 - custom_mape_loss: 0.8917 - val_loss: 1.0290 - val_custom_mape_loss: 1.0686 - lr: 1.0000e-04

# %%
def predecir_todos_t2(df_features_full, scalers, feature_cols):
    """
    Predice tn en t+2 para todos los productos que tengan suficientes datos.

    Args:
        df_features_full (pd.DataFrame): dataframe completo con features
        model: modelo LSTM ya entrenado
        scalers (dict): diccionario con los StandardScaler por producto
        feature_cols (list): lista de columnas de features
        window_size (int): tamaño de la ventana temporal

    Returns:
        pd.DataFrame: dataframe con columnas ["product_id", "tn_t2_pred"]
    """
    productos = df_features_full["product_id"].unique()
    resultados = []
    errores = []
    for pid in productos:
        y_pred = None
        df_prod = df_features_full[df_features_full["product_id"] == pid]
        grupo = df_prod["grupo"].iloc[0] if not df_prod.empty else 0
        window_size = get_window_size(grupo)
        if len(df_prod) < window_size:
            y_pred = np.mean(df_prod["tn"][-12:])  # Valor por defecto si falla la predicción
            resultados.append({"product_id": pid, "tn_t2_pred": y_pred})
            continue  # no hay suficientes datos

        try:
            ultimos = df_prod[feature_cols].iloc[-window_size:]
            scaler = scalers[pid]
            ultimos_scaled = scaler.transform(ultimos)

            # Agregar la feature extra
            mes_ultimo_valor = df_prod.iloc[-1]["month"]
            quarter_ultimo_valor = df_prod.iloc[-1]["quarter"]
            
            mes_scaled = (mes_ultimo_valor - 1) / 11
            quarter_scaled = (quarter_ultimo_valor - 1) / 3


            mes_feature = np.full((window_size, 1), mes_scaled)
            quarter_feature = np.full((window_size, 1), quarter_scaled)

            X_new = np.concatenate([ultimos_scaled, mes_feature, quarter_feature], axis=1).reshape(1, window_size, -1)
            model = modelos[int(df_prod["grupo"].iloc[0])]  # Obtener el modelo según el quantil
            y_pred_scaled = model.predict(X_new, verbose=0)

            # Desescalar
            tn_mean = scaler.center_[0]
            tn_std = scaler.scale_[0]
            y_pred = y_pred_scaled[0][0] * tn_std + tn_mean

            

        except Exception as e:
            errores.append(pid)
            #print(f"Error al predecir producto {pid}: {e}")
            
        if y_pred is None or y_pred < 0:
            y_pred = np.mean(df_prod["tn"][-12:])  # Valor por defecto si falla la predicción

            
        resultados.append({"product_id": pid, "tn_t2_pred": y_pred})

    print(f"Errores en predicciones: {errores} de {len(productos)} productos")
    return pd.DataFrame(resultados), errores

# %%
df_preds_t2, errores = predecir_todos_t2(
    df_features_full=df_features,
    scalers=scalers,
    feature_cols=feature_cols,
    #window_size=window_size
)
print(f"Errores: {len(errores)} de {len(df_features['product_id'].unique())} productos")
print(df_preds_t2.head())
# Out:
# Errores en predicciones: [20127, 20210, 20621, 20662, 20673, 20711, 20720, 20732, 20774, 20827, 20904, 20910, 20912, 20927, 20933, 21006, 21007, 21035, 21039, 21079, 21109, 21111, 21112, 21114, 21119, 21140, 21227] de 780 productos
# Errores: 27 de 780 productos
#    product_id   tn_t2_pred
# 0       20001  1282.423369
# 1       20002   895.847687
# 2       20003   712.372982
# 3       20004   482.133539
# 4       20005   437.671462

# %%
df_preds_t2
# Out:
#      product_id   tn_t2_pred
# 0         20001  1282.423369
# 1         20002   895.847687
# 2         20003   712.372982
# 3         20004   482.133539
# 4         20005   437.671462
# ..          ...          ...
# 775       21263     0.011982
# 776       21265     0.024516
# 777       21266     0.029611
# 778       21267     0.025542
# 779       21276     0.045447
#
# [780 rows x 2 columns]

# %%
dforig = pd.read_csv("../datasets/sell-in.txt.gz", sep="\t")
total_diciembre = dforig.query("periodo == 201912")["tn"].sum()
df_preds_t2["tn_t2_pred"] = df_preds_t2["tn_t2_pred"]

# %%
df_final = df_test.merge(df_preds_t2, on="product_id", how="left")
df_final
# Out:
#      product_id    periodo          tn  grupo     tn_lag1   tn_diff1  \
# 0         20001 2019-12-01  1504.68856      4  1397.37231  107.31625
# 1         20002 2019-12-01  1087.30855      4  1423.57739 -336.26884
# 2         20003 2019-12-01   892.50129      4   948.29393  -55.79264
# 3         20004 2019-12-01   637.90002      4   723.94206  -86.04204
# 4         20005 2019-12-01   593.24443      4   606.91173  -13.66730
# ..          ...        ...         ...    ...         ...        ...
# 775       21263 2019-12-01     0.01270      0     0.03247   -0.01977
# 776       21265 2019-12-01     0.05007      0     0.06600   -0.01593
# 777       21266 2019-12-01     0.05121      0     0.06713   -0.01592
# 778       21267 2019-12-01     0.01569      0     0.04052   -0.02483
# 779       21276 2019-12-01     0.00892      0     0.03341   -0.02449
#
#           sin_mes  quarter  month  rolling_mean6  rolling_std6   tn_t2_pred
# 0   -2.449294e-16        4     12    1444.859933    229.267460  1282.423369
# 1   -2.449294e-16        4     12    1216.982983    426.327986   895.847687
# 2   -2.449294e-16        4     12     835.102808    187.119671   712.372982
# 3   -2.449294e-16        4     12     707.642135    210.228042   482.133539
# 4   -2.449294e-16        4     12     773.672883    176.802640   437.671462
# ..            ...      ...    ...            ...           ...          ...
# 775 -2.449294e-16        4     12       0.022817      0.011760     0.011982
# 776 -2.449294e-16        4     12       0.048168      0.035791     0.024516
# 777 -2.449294e-16        4     12       0.056698      0.036011     0.029611
# 778 -2.449294e-16        4     12       0.054910      0.027947     0.025542
# 779 -2.449294e-16        4     12       0.021417      0.013967     0.045447
#
# [780 rows x 12 columns]

# %%
numerador = (df_final["tn"]- df_final["tn_t2_pred"]).abs().sum()
denominador = df_final["tn"].sum()
porcentaje_error = (numerador / denominador)
porcentaje_error
# Out:
# 0.2086986104099551

# %%
import matplotlib.pyplot as plt
df_final.plot(kind="scatter", x="tn", y="tn_t2_pred", title="Predicciones vs TN")
plt.plot([0, 6], [0, 6], 'r--')
plt.show()

# %%
import plotly.graph_objects as go

# Crear el gráfico de dispersión
fig = go.Figure()

# Añadir los puntos de dispersión con el product_id en el hover
fig.add_trace(go.Scatter(
    x=df_final["tn"],
    y=df_final["tn_t2_pred"],
    mode='markers',
    name='Datos',
    customdata=df_final["product_id"],  # Pasamos el product_id como dato adicional
    hovertemplate=(
        "<b>TN Real</b>: %{x}<br>"
        "<b>TN Predicho</b>: %{y}<br>"
        "<b>Product ID</b>: %{customdata}<br>"
        "<extra></extra>"  # Elimina información adicional automática
    ),
    marker=dict(size=8, opacity=0.7)  # Opcional: ajustar tamaño y transparencia
))

# Añadir la línea de referencia y=x
fig.add_trace(go.Scatter(
    x=[0, 1400],
    y=[0, 1400],
    mode='lines',
    name='y = x',
    line=dict(color='red', dash='dash')
))

# Configurar el diseño del gráfico para que sea cuadrado
fig.update_layout(
    title='Predicciones vs TN',
    xaxis_title='TN Real',
    yaxis_title='TN Predicho',
    showlegend=True,
    # Forzar misma escala en ejes X e Y
    xaxis=dict(scaleanchor="y", scaleratio=1),
    yaxis=dict(scaleanchor="x", scaleratio=1),
    # Tamaño cuadrado (opcional)
    width=600,
    height=600,
    # Rango fijo para ambos ejes (opcional)
    xaxis_range=[0, 1500],
    yaxis_range=[0, 1500]
)

# Mostrar el gráfico
fig.show()

# %%
print(df_final["tn_t2_pred"].sum(),"|",df_final["tn"].sum())
# Out:
# 24928.480734102195 | 25145.252080000002

# %%
df_final["error"] = (df_final["tn"] - df_final["tn_t2_pred"]).abs()
df_final["error_relativo"] = df_final["error"] / df_final["tn"]
df_final.sort_values(by="error", ascending=False, inplace=True)
df_final[["product_id" ,"tn", "tn_t2_pred", "error", "error_relativo"]].head(20)
# Out:
#     product_id          tn   tn_t2_pred       error  error_relativo
# 0        20001  1504.68856  1282.423369  222.265191        0.147715
# 7        20008   195.36854   396.215782  200.847242        1.028043
# 1        20002  1087.30855   895.847687  191.460863        0.176087
# 2        20003   892.50129   712.372982  180.128308        0.201824
# 3        20004   637.90002   482.133539  155.766481        0.244186
# 4        20005   593.24443   437.671462  155.572968        0.262241
# 27       20028   109.92618   210.101837  100.175657        0.911299
# 11       20012   173.13004   270.528962   97.398922        0.562577
# 10       20011   392.38290   303.878624   88.504276        0.225556
# 17       20018   141.63570   228.342084   86.706384        0.612179
# 13       20014   272.02812   352.252464   80.224344        0.294912
# 23       20024   270.45018   196.092934   74.357246        0.274939
# 43       20047    71.49763   144.491677   72.994047        1.020930
# 18       20019   351.54708   279.848747   71.698333        0.203951
# 8        20009   495.03574   424.158456   70.877284        0.143176
# 40       20044    59.61747   129.595353   69.977883        1.173781
# 72       20080     8.84426    77.690421   68.846161        7.784276
# 32       20033    96.76212   157.514053   60.751933        0.627848
# 89       20100     1.37920    59.965724   58.586524       42.478628
# 26       20027   155.25876   212.248979   56.990219        0.367066

# %%
sellin = pd.read_csv("../datasets/sell-in.txt.gz", sep="\t")

# %%
# prod = 20995
# prod_s = sellin[sellin["product_id"] == prod]
# prod_s["periodo"] = pd.to_datetime(prod_s["periodo"], format='%Y%m')
# prod_s = prod_s.groupby("periodo").agg({"tn": "sum"}).reset_index()
# #prod_s.plot(kind="line", x="periodo", y="tn", title="TN por periodo para producto 20002")

# import matplotlib.pyplot as plt

# ax = plt.gca()
# prod_s.plot(kind="line", x="periodo", y="tn", title=f"TN por periodo para producto {prod}", ax=ax)
# #plt.axhline(y=813.82, color='red', linestyle='--', label='predict')
# prediccion = df_final[df_final["product_id"] == prod]["tn_t2_pred"].values[0]
# plt.scatter(prod_s["periodo"].iloc[-1], prediccion, color='red', label='prediccion')
# plt.legend()
# plt.show()

# %%
df_final["volumen_cuartil"] = pd.qcut(df_final["tn"], q=10, labels=False)

# %%
print(df_final.groupby("volumen_cuartil")[["error"]].sum())
# Out:
#                        error
# volumen_cuartil
# 0                  50.140240
# 1                  79.623016
# 2                 136.438717
# 3                  87.283838
# 4                 159.109616
# 5                 247.962959
# 6                 169.762552
# 7                 459.612883
# 8                 988.764723
# 9                2869.080623

# %%
metricas
# Out:
# {0: {'loss': 0.8366174697875977, 'mae': 0.8415180444717407},
#  1: {'loss': 0.6596412062644958, 'mae': 0.656760573387146},
#  2: {'loss': 0.7656846046447754, 'mae': 0.8050817251205444},
#  3: {'loss': 0.8370221853256226, 'mae': 0.8206144571304321},
#  4: {'loss': 0.8520306348800659, 'mae': 0.8556522130966187}}

# %%
df_preds_t2, errores = predecir_todos_t2(
    df_features_full=df,
    scalers=scalers,
    feature_cols=feature_cols,
    #window_size=window_size
)
# Out:
# Errores en predicciones: [20127, 20210, 20621, 20662, 20673, 20711, 20720, 20732, 20774, 20827, 20904, 20910, 20912, 20927, 20933, 21006, 21007, 21035, 21039, 21079, 21109, 21111, 21112, 21114, 21119, 21140, 21227] de 780 productos

# %%
total_diciembre = sellin.query("periodo == 201912")["tn"].sum()

# %%
productos_ok = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/product_id_apredecir201912.txt", sep="\t")

pred = pd.DataFrame({"product_id": df_preds_t2["product_id"],  "tn": df_preds_t2["tn_t2_pred"]})
#pred["tn"] = pred["tn"] * total_diciembre/100 *0.9
pred = pred[pred["product_id"].isin(productos_ok["product_id"])]
result_name = config["result_name"]
result_name = "LSTM_Q5_withmonth"  # IGNORE
pred.to_csv(f"{result_name}.csv", sep=",", index=False)

# %%
pred
# Out:
#      product_id           tn
# 0         20001  1282.423369
# 1         20002   895.847687
# 2         20003   712.372982
# 3         20004   482.133539
# 4         20005   437.671462
# ..          ...          ...
# 775       21263     0.011982
# 776       21265     0.024516
# 777       21266     0.029611
# 778       21267     0.025542
# 779       21276     0.045447
#
# [780 rows x 2 columns]

# %%
df_preds_t2[df_preds_t2["product_id"].isin(productos_ok["product_id"])].product_id.nunique()
# Out:
# 780

# %%
pred.drop_duplicates(subset=["product_id"], inplace=True)

# %%
pred
# Out:
#      product_id           tn
# 0         20001  1282.423369
# 1         20002   895.847687
# 2         20003   712.372982
# 3         20004   482.133539
# 4         20005   437.671462
# ..          ...          ...
# 775       21263     0.011982
# 776       21265     0.024516
# 777       21266     0.029611
# 778       21267     0.025542
# 779       21276     0.045447
#
# [780 rows x 2 columns]
